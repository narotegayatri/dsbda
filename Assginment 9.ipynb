# %%
import seaborn as sns

# %%
data = sns.load_dataset('titanic')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.boxplot(data = data, x='sex', y='age', hue='survived')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.boxplot(data=data,x='sex',y='age')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
data_survived = data.where(data['survived']==1).dropna()
data_survived.head(5)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1        1.0     1.0  female  38.0    1.0    0.0  71.2833        C   First
# 3        1.0     1.0  female  35.0    1.0    0.0  53.1000        S   First
# 10       1.0     3.0  female   4.0    1.0    1.0  16.7000        S   Third
# 11       1.0     1.0  female  58.0    0.0    0.0  26.5500        S   First
# 21       1.0     2.0    male  34.0    0.0    0.0  13.0000        S  Second
#
#       who adult_male deck  embark_town alive  alone
# 1   woman      False    C    Cherbourg   yes  False
# 3   woman      False    C  Southampton   yes  False
# 10  child      False    G  Southampton   yes  False
# 11  woman      False    C  Southampton   yes   True
# 21    man       True    D  Southampton   yes   True

# %%
sns.boxplot(data=data_survived,x='sex',y='age')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
data_not_survived = data.where(data['survived']!=1).dropna()
data_not_survived.head(5)
# Out:
#     survived  pclass   sex   age  sibsp  parch      fare embarked  class  who  \
# 6        0.0     1.0  male  54.0    0.0    0.0   51.8625        S  First  man
# 27       0.0     1.0  male  19.0    3.0    2.0  263.0000        S  First  man
# 54       0.0     1.0  male  65.0    0.0    1.0   61.9792        C  First  man
# 62       0.0     1.0  male  45.0    1.0    0.0   83.4750        S  First  man
# 75       0.0     3.0  male  25.0    0.0    0.0    7.6500        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 6        True    E  Southampton    no   True
# 27       True    C  Southampton    no  False
# 54       True    B    Cherbourg    no  False
# 62       True    C  Southampton    no  False
# 75       True    F  Southampton    no   True

# %%
sns.boxplot(data=data_not_survived,x='sex',y='age')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>
